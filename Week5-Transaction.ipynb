# %% [markdown]
# <a href="https://colab.research.google.com/github/marsya505/DataMining/blob/main/Week5-Transaction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mixtend
# Out:
# ERROR: Could not find a version that satisfies the requirement mixtend (from versions: none)
# ERROR: No matching distribution found for mixtend
